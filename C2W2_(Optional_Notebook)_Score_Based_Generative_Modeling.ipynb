# %% [markdown]
# <a href="https://colab.research.google.com/github/avani17101/Coursera-GANs-Specialization/blob/main/C2W2_(Optional_Notebook)_Score_Based_Generative_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Score-Based Generative Modeling
#
# *Please note that this is an optional notebook meant to introduce more advanced concepts. If you’re up for a challenge, take a look and don’t worry if you can’t follow everything. There is no code to implement—only some cool code for you to learn and run!*
#
# ### Goals
# This is a hitchhiker's guide to score-based generative models, a family of approaches based on [estimating gradients of the data distribution](https://arxiv.org/abs/1907.05600). They have obtained high-quality samples comparable to GANs (like below, figure from [this paper](https://arxiv.org/abs/2006.09011)) without requiring adversarial training, and are considered by some to be [the new contender to GANs](https://ajolicoeur.wordpress.com/the-new-contender-to-gans-score-matching-with-langevin-sampling/).
#
# ![ncsnv2](https://github.com/ermongroup/ncsnv2/blob/master/assets/samples.jpg?raw=true)

# %% [markdown]
# ## Introduction
#
# ### Score and Score-Based Models
# Given a probablity density function $p(\mathbf{x})$, we define the *score* as $$\nabla_\mathbf{x} \log p(\mathbf{x}).$$ As you might guess, score-based generative models are trained to estimate $\nabla_\mathbf{x} \log p(\mathbf{x})$. Unlike likelihood-based models such as flow models or autoregressive models, score-based models do not have to be normalized and are easier to parameterize. For example, consider a non-normalized statistical model $p_\theta(\mathbf{x}) = \frac{e^{-E_\theta(\mathbf{x})}}{Z_\theta}$, where $E_\theta(\mathbf{x}) \in \mathbb{R}$ is called the energy function and $Z_\theta$ is an unknown normalizing constant that makes $p_\theta(\mathbf{x})$ a proper probability density function. The energy function is typically parameterized by a flexible neural network. When training it as a likelihood model, we need to know the normalizing constant $Z_\theta$ by computing complex high-dimensional integrals, which is typically intractable. In constrast, when computing its score, we obtain $\nabla_\mathbf{x} \log p_\theta(\mathbf{x}) = -\nabla_\mathbf{x} E_\theta(\mathbf{x})$ which does not require computing the normalizing constant $Z_\theta$.
#
# In fact, any neural network that maps an input vector $\mathbf{x} \in \mathbb{R}^d$ to an output vector $\mathbf{y} \in \mathbb{R}^d$ can be used as a score-based model, as long as the output and input have the same dimensionality. This yields huge flexibility in choosing model architectures.
#
# ### Perturbing Data with a Diffusion Process
#
# In order to generate samples with score-based models, we need to consider a [diffusion process](https://en.wikipedia.org/wiki/Diffusion_process) that corrupts data slowly into random noise. Scores will arise when we reverse this diffusion process for sample generation. You will see this later in the notebook.
#
# A diffusion process is a [stochastic process](https://en.wikipedia.org/wiki/Stochastic_process#:~:text=A%20stochastic%20or%20random%20process%20can%20be%20defined%20as%20a,an%20element%20in%20the%20set.) similar to [Brownian motion](https://en.wikipedia.org/wiki/Brownian_motion). Their paths are like the trajectory of a particle submerged in a flowing fluid, which moves randomly due to unpredictable collisions with other particles. Let $\{\mathbf{x}(t) \in \mathbb{R}^d \}_{t=0}^T$ be a diffusion process, indexed by the continuous time variable $t\in [0,T]$. A diffusion process is governed by a stochastic differential equation (SDE), in the following form
#
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
#
# where $\mathbf{f}(\cdot, t): \mathbb{R}^d \to \mathbb{R}^d$ is called the *drift coefficient* of the SDE, $g(t) \in \mathbb{R}$ is called the *diffusion coefficient*, and $\mathbf{w}$ represents the standard Brownian motion. You can understand an SDE as a stochastic generalization to ordinary differential equations (ODEs). Particles moving according to an SDE not only follows the deterministic drift $\mathbf{f}(\mathbf{x}, t)$, but are also affected by the random noise coming from $g(t) d\mathbf{w}$.
#
# For score-based generative modeling, we will choose a diffusion process such that $\mathbf{x}(0) \sim p_0$, where we have a dataset of i.i.d. samples, and $\mathbf{x}(T) \sim p_T$, for which we have a tractable form to sample from.
#
# ### Reversing the Diffusion Process Yields Score-Based Generative Models
# By starting from a sample from $p_T$ and reversing the diffusion process, we will be able to obtain a sample from $p_\text{data}$. Crucially, the reverse process is a diffusion process running backwards in time. It is given by the following reverse-time SDE
#
# \begin{align}
#   d\mathbf{x} = [\mathbf{f}(\mathbf{x}, t) - g^2(t)\nabla_{\mathbf{x}}\log p_t(\mathbf{x})] dt + g(t) d\bar{\mathbf{w}},
# \end{align}
#
# where $\bar{\mathbf{w}}$ is a Brownian motion in the reverse time direction, and $dt$ here represents an infinitesimal negative time step. Here $p_t(\mathbf{x})$ represents the distribution of $\mathbf{x}(t)$. This reverse SDE can be computed once we know the drift and diffusion coefficients of the forward SDE, as well as the score of $p_t(\mathbf{x})$ for each $t\in[0, T]$.
#
# The overall intuition of score-based generative modeling with SDEs can be summarized in the illustration below
# ![sde schematic](https://github.com/https-deeplearning-ai/GANs-Public/blob/master/diffusion_schematic.jpg?raw=true)
#
# ### Score Estimation
#
# Based on the above intuition, we can use the time-dependent score function $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ to construct the reverse-time SDE, and then solve it numerically to obtain samples from $p_0$ using samples from a prior distribution $p_T$. We can train a time-dependent score-based model $s_\theta(\mathbf{x}, t)$ to approximate $\nabla_\mathbf{x} \log p_t(\mathbf{x})$, using the following weighted sum of [denoising score matching](http://www.iro.umontreal.ca/~vincentp/Publications/smdae_techreport.pdf) objectives.
#
# \begin{align}
# \min_\theta \mathbb{E}_{t\sim \mathcal{U}(0, T)} [\lambda(t) \mathbb{E}_{\mathbf{x}(0) \sim p_0(\mathbf{x})}\mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]],
# \end{align}
# where $\mathcal{U}(0,T)$ is a uniform distribution over $[0, T]$, $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$ denotes the transition probability from $\mathbf{x}(0)$ to $\mathbf{x}(t)$, and $\lambda(t) \in \mathbb{R}^+$ denotes a continuous weighting function.
#
# In the objective, the expectation over $\mathbf{x}(0)$ can be estimated with empirical means over data samples from $p_0$. The expectation over $\mathbf{x}(t)$ can be estimated by sampling from $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$, which is efficient when the drift coefficient $\mathbf{f}(\mathbf{x}, t)$ is affine. The weight function $\lambda(t)$ is typically chosen to be inverse proportional to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]$.

# %% [markdown]
# ### Time-Dependent Score-Based Model
#
# There are no restrictions on the network architecture of time-dependent score-based models, except that their output should have the same dimensionality as the input, and they should be conditioned on time.
#
# Several useful tips on architecture choice:
# * It usually performs well to use the [U-net](https://arxiv.org/abs/1505.04597) architecture as the backbone of the score network $s_\theta(\mathbf{x}, t)$,
#
# * We can incorporate the time information via [Gaussian random features](https://arxiv.org/abs/2006.10739). Specifically, we first sample $\omega \sim \mathcal{N}(\mathbf{0}, s^2\mathbf{I})$ which is subsequently fixed for the model (i.e., not learnable). For a time step $t$, the corresponding Gaussian random feature is defined as
# \begin{align}
#   [\sin(2\pi \omega t) ; \cos(2\pi \omega t)],
# \end{align}
# where $[\vec{a} ; \vec{b}]$ denotes the concatenation of vector $\vec{a}$ and $\vec{b}$. This Gaussian random feature can be used as an encoding for time step $t$ so that the score network can condition on $t$ by incorporating this encoding. We will see this further in the code.
#
# * We can rescale the output of the U-net by $1/\sqrt{\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]}$. This is because the optimal $s_\theta(\mathbf{x}(t), t)$ has an $\ell_2$-norm close to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))]\|_2$, and the rescaling helps capture the norm of the true score. Recall that the training objective contains sums of the form
# \begin{align*}
# \mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]].
# \end{align*}
# Therefore, it is natural to expect that the optimal score model $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$.
#
# * Use [exponential moving average](https://discuss.pytorch.org/t/how-to-apply-exponential-moving-average-decay-for-variables/10856/3) (EMA) of weights when sampling. This can greatly improve sample quality, but requires slightly longer training time, and requires more work in implementation. We do not include this in this tutorial, but highly recommend it when you employ score-based generative modeling to tackle more challenging real problems.

# %%
#@title Defining a time-dependent score-based model (double click to expand or collapse)

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class GaussianFourierProjection(nn.Module):
  """Gaussian random features for encoding time steps."""  
  def __init__(self, embed_dim, scale=8.):
    super().__init__()
    # Randomly sample weights during initialization. These weights are fixed 
    # during optimization and are not trainable.
    self.W = nn.Parameter(torch.randn(embed_dim // 2) * scale, requires_grad=False)
  def forward(self, x):
    x_proj = x[:, None] * self.W[None, :] * 2 * np.pi
    return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)


class Dense(nn.Module):
  """A fully connected layer that reshapes outputs to feature maps."""
  def __init__(self, input_dim, output_dim):
    super().__init__()
    self.dense = nn.Linear(input_dim, output_dim)
  def forward(self, x):
    return self.dense(x)[..., None, None]


class ScoreNet(nn.Module):
  """A time-dependent score-based model built upon U-Net architecture."""

  def __init__(self, noise_scale, channels=[32, 64, 128, 256], embed_dim=256):
    """
      Initialize a time-dependent score-based network.

      noise_scale: 
        a function that takes time t and gives the variance of 
        the perturbation kernel p_{0t}(x(t) | x(0)).
      channels: 
        the number of channels for feature maps of each resolution.
      embed_dim:
        the dimensionality of Gaussian random feature embeddings.
    """
    super().__init__()
    # Gaussian random feature embedding layer for time
    self.embed = GaussianFourierProjection(embed_dim=embed_dim)    
    # Encoding layers where the resolution decreases
    self.conv1 = nn.Conv2d(1, channels[0], 3, stride=1, bias=False)
    self.dense1 = Dense(embed_dim, channels[0])
    self.gnorm1 = nn.GroupNorm(4, num_channels=channels[0])
    self.conv2 = nn.Conv2d(channels[0], channels[1], 3, stride=2, bias=False)
    self.dense2 = Dense(embed_dim, channels[1])
    self.gnorm2 = nn.GroupNorm(32, num_channels=channels[1])
    self.conv3 = nn.Conv2d(channels[1], channels[2], 3, stride=2, bias=False)
    self.dense3 = Dense(embed_dim, channels[2])
    self.gnorm3 = nn.GroupNorm(32, num_channels=channels[2])
    self.conv4 = nn.Conv2d(channels[2], channels[3], 3, stride=2, bias=False)
    self.dense4 = Dense(embed_dim, channels[3])
    self.gnorm4 = nn.GroupNorm(32, num_channels=channels[3])    

    # Decoding layers where the resolution increases
    self.tconv4 = nn.ConvTranspose2d(channels[3], channels[2], 3, stride=2, bias=False)
    self.dense5 = Dense(embed_dim, channels[2])
    self.tgnorm4 = nn.GroupNorm(32, num_channels=channels[2])
    self.tconv3 = nn.ConvTranspose2d(channels[2] + channels[2], channels[1], 3, stride=2, bias=False, output_padding=1)    
    self.dense6 = Dense(embed_dim, channels[1])
    self.tgnorm3 = nn.GroupNorm(32, num_channels=channels[1])
    self.tconv2 = nn.ConvTranspose2d(channels[1] + channels[1], channels[0], 3, stride=2, bias=False, output_padding=1)    
    self.dense7 = Dense(embed_dim, channels[0])
    self.tgnorm2 = nn.GroupNorm(32, num_channels=channels[0])
    self.tconv1 = nn.ConvTranspose2d(channels[0] + channels[0], 1, 3, stride=1)
    
    # The swish activation function
    self.act = lambda x: x * torch.sigmoid(x)
    self.noise_scale = noise_scale
  
  def forward(self, x, t): 
    # Obtain the Gaussian random feature embedding for t   
    embed = self.act(self.embed(t))    
    # Encoding path
    h1 = self.conv1(x)    
    ## Incorporate information from t
    h1 += self.dense1(embed)
    ## Group normalization
    h1 = self.gnorm1(h1)
    h1 = self.act(h1)
    h2 = self.conv2(h1)
    h2 += self.dense2(embed)
    h2 = self.gnorm2(h2)
    h2 = self.act(h2)
    h3 = self.conv3(h2)
    h3 += self.dense3(embed)
    h3 = self.gnorm3(h3)
    h3 = self.act(h3)
    h4 = self.conv4(h3)
    h4 += self.dense4(embed)
    h4 = self.gnorm4(h4)
    h4 = self.act(h4)

    # Decoding path
    h = self.tconv4(h4)
    ## Skip connection from the encoding path
    h += self.dense5(embed)
    h = self.tgnorm4(h)
    h = self.act(h)
    h = self.tconv3(torch.cat([h, h3], dim=1))
    h += self.dense6(embed)
    h = self.tgnorm3(h)
    h = self.act(h)
    h = self.tconv2(torch.cat([h, h2], dim=1))
    h += self.dense7(embed)
    h = self.tgnorm2(h)
    h = self.act(h)
    h = self.tconv1(torch.cat([h, h1], dim=1))

    # Normalize output based on the norm of perturbation kernels.
    h = h / self.noise_scale(t)[:, None, None, None]
    return h

# %% [markdown]
# ## Training with Weighted Sum of Denoising Score Matching Objectives
#
# Now let's get our hands dirty on training. First of all, we need to specify an SDE that perturbs the data distribution $p_0$ to a prior distribution $p_T$. We choose the following SDE
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. In this case,
# \begin{align*}
# p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) = \mathcal{N}(\mathbf{x}(t); \mathbf{x}(0), [\sigma^2(t) - \sigma^2(0)]\mathbf{I})
# \end{align*}
# and $\lambda(t) \propto \sigma^2(t) - \sigma^2(0)$.
#
# When $\sigma_{\text{max}}$ is large enough, the distribution of $p_1$ is
# \begin{align*}
# \int p_0(\mathbf{y})\mathcal{N}(\mathbf{x}; \mathbf{y}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}) d \mathbf{y} \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}),
# \end{align*}
# which is easy to sample from.
#
# Intuitively, this SDE captures a continuum of Gaussian perturbations with variance function $\sigma(t)^2 - \sigma^2(0)$, where $\sigma(t)$ is a strictly increasing function that grows exponentially fast. This continuum of perturbations allows us to gradually transfer samples from a data distribution $p_0$ to a simple Gaussian distribution $p_1$.

# %%
#@title Loss function (double click to expand or collapse)
def noise_scale(t, sigma_min=0.01, sigma_max=10, grad=False):
  """
  Compute quantities related to the perturbation kernel p_{0t}(x(t) | x(0)).

  t: a vector of time steps.
  sigma_min: the minimum value of the sigma function.
  sigma_max: the maximum value of the sigma function.
  grad: if False, only return the variance of p_{0t}(x(t) | x(0)). 
    Otherwise return both the variance and the gradient of sigma^2(t).
    This gradient will be useful for sample generation.
  """
  noise = sigma_min * (sigma_max / sigma_min)**t
  if not grad:
    return torch.sqrt(noise**2 - sigma_min**2)
  else:
    dnoise_dt = sigma_min * (sigma_max / sigma_min)**t * np.log(sigma_max/sigma_min)
    dnoise2_dt = 2 * noise * dnoise_dt
    return torch.sqrt(noise**2 - sigma_min**2), dnoise2_dt

def loss_func(model, x, noise_scale, eps=1e-3):
  """
  The loss function for training score-based generative models.

  model: a PyTorch model instance that represents a time-dependent score-based model.
  x: a mini-batch of input images.
  noise_scale: a function that computes the variance of perturbation kernels.
  eps: a tolerance value for numerical stability.
  """
  random_t = torch.rand(x.shape[0], device=x.device) * (1. - eps) + eps
  noise_scales = noise_scale(random_t)
  z = torch.randn_like(x)
  perturbed_x = x + z * noise_scales[:, None, None, None]
  score = model(perturbed_x, random_t)
  loss = torch.sum((score * noise_scales[:, None, None, None] + z).reshape(x.shape[0], -1)**2, dim=-1).mean()
  return loss

# %%
#@title Training (double click to expand or collapse)

import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
import tqdm

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

sigma_min = 0.01 #@param {'type':'number'}
sigma_max = 22 #@param {'type':'number'}
noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=False)
score_model = torch.nn.DataParallel(ScoreNet(noise_scale=noise_scale_func))
score_model = score_model.to(device)

n_epochs =  50 #@param {'type':'integer'}
## size of a mini-batch
batch_size =  32 #@param {'type':'integer'}
## learning rate
lr=1e-4 #@param {'type':'number'}

dataset = MNIST('.', train=True, transform=transforms.ToTensor(), download=True)
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

optimizer = Adam(score_model.parameters(), lr=lr)
for epoch in range(n_epochs):
  avg_loss = 0.
  num_items = 0
  for x, y in tqdm.notebook.tqdm(data_loader):
    optimizer.zero_grad()
    x = x.to(device)    
    loss = loss_func(score_model, x, noise_scale_func)
    loss.backward()
    optimizer.step()
    avg_loss += loss.item() * x.shape[0]
    num_items += x.shape[0]
  # Print the averaged training loss so far.
  print(f'epoch: {epoch}, average loss: {avg_loss / num_items}')
  # Save one checkpoint after each epoch of training.
  torch.save(score_model.state_dict(), f'ckpt.pth')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 0, average loss: 483.51244572753905
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 1, average loss: 194.39902650553387
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 2, average loss: 145.89893876953124
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 3, average loss: 126.51463119913737
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 4, average loss: 115.66338969523112
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 5, average loss: 107.21261338500976
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 6, average loss: 101.48795166219075
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 7, average loss: 96.42930077514649
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 8, average loss: 94.13556114705403
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 9, average loss: 90.84001868693034
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 10, average loss: 88.22724880574545
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 11, average loss: 85.90303047281901
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 12, average loss: 84.3092524983724
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 13, average loss: 82.27248398640951
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 14, average loss: 80.10301864827474
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 15, average loss: 79.79542090657552
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 16, average loss: 78.16782538655599
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 17, average loss: 77.3873672261556
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 18, average loss: 75.15147934163411
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 19, average loss: 75.05600303955079
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 20, average loss: 74.52022091064453
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 21, average loss: 73.41639514363607
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 22, average loss: 72.86841547851563
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 23, average loss: 72.05855472005209
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 24, average loss: 71.32706161905925
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 25, average loss: 70.80785100911459
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 26, average loss: 70.0501092183431
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 27, average loss: 69.67279721272786
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 28, average loss: 69.30615202229818
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 29, average loss: 68.57433032023113
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 30, average loss: 68.09683931172688
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 31, average loss: 67.72526303914388
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 32, average loss: 67.17570736796061
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 33, average loss: 66.67623248189291
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 34, average loss: 66.38500634358724
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 35, average loss: 65.95370077616374
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 36, average loss: 65.03816036071777
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 37, average loss: 65.78841054077148
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 38, average loss: 64.68718348795574
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 39, average loss: 64.40487002156576
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 40, average loss: 64.48890493367513
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 41, average loss: 63.227957316080726
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 42, average loss: 63.51039096476237
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 43, average loss: 63.395563796997074
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 44, average loss: 63.1504443745931
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 45, average loss: 62.81269328715007
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 46, average loss: 62.78231496887207
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 47, average loss: 62.21141225382487
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 48, average loss: 61.433864627075195
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 49, average loss: 61.38967848917643

# %% [markdown]
# ## Sampling with Numerical SDE Solvers
# Recall that for any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt + g(t) d\mathbf{w},
# \end{align*}
# the reverse-time SDE is given by
# \begin{align*}
# d \mathbf{x} = [\mathbf{f}(\mathbf{x}, t) + g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})] dt + g(t) d \bar{\mathbf{w}}.
# \end{align*}
# Since we have chosen the forward SDE to be
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. The reverse-time SDE is given by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} \nabla_\mathbf{x} \log p_t(\mathbf{x}) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}.
# \end{align*}
# To sample from our time-dependent score-based model $s_\theta(\mathbf{x}, t)$, we can first draw a sample from $p_1 \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I})$, and then solve the reverse-time SDE with numerical methods.
#
# Specifically, using our time-dependent score-based model, the reverse-time SDE can be approximated by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} s_\theta(\mathbf{x}, t) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}
# \end{align*}
#
# Next, one can use numerical methods to solve for the reverse-time SDE, such as the [Euler-Maruyama](https://en.wikipedia.org/wiki/Euler%E2%80%93Maruyama_method) approach. It is based on a simple discretization to the SDE, replacing $dt$ with $\Delta t$ and $d \mathbf{w}$ with $\mathbf{z} \sim \mathcal{N}(\mathbf{0}, g^2(t) \Delta t \mathbf{I})$. When applied to our reverse-time SDE, we can obtain the following iteration rule
# \begin{align}
# \mathbf{x}_{t-\Delta t} = \mathbf{x}_t + \frac{d[\sigma^2(t)]}{dt}s_\theta(\mathbf{x}_t, t)\Delta t + \sqrt{\frac{d[\sigma^2(t)]}{dt}\Delta t} \mathbf{z}_t,
# \end{align}
# where $\mathbf{z}_t \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$.

# %% [markdown]
# ## Sampling with Predictor-Corrector Methods
#
# Aside from generic numerical SDE solvers, we can leverage special properties of our reverse-time SDE for better solutions. Since we have an estimate of the score of $p_t(\mathbf{x}(t))$ via the score-based model, i.e., $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_t(\mathbf{x}(t))$, we can leverage score-based MCMC approaches, such as Langevin MCMC, to correct the solution obtained by numerical SDE solvers.
#
# Score-based MCMC approaches can produce samples from a distribution $p(\mathbf{x})$ once its score $\nabla_\mathbf{x} \log p(\mathbf{x})$ is known. For example, Langevin MCMC operates by running the following iteration rule for $i=1,2,\cdots, N$:
# \begin{align*}
# \mathbf{x}_{i+1} = \mathbf{x}_{i} + \epsilon \nabla_\mathbf{x} \log p(\mathbf{x}_i) + \sqrt{2\epsilon} \mathbf{z}_i,
# \end{align*}
# where $\mathbf{z}_i \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, $\epsilon > 0$ is the step size, and $\mathbf{x}_1$ is initialized from any prior distribution $\pi(\mathbf{x}_1)$. When $N\to\infty$ and $\epsilon \to 0$, the final value $\mathbf{x}_{N+1}$ becomes a sample from $p(\mathbf{x})$ under some regularity conditions. Therefore, given $s_\theta(\mathbf{x}, t) \approx \nabla_\mathbf{x} \log p_t(\mathbf{x})$, we can get an approximate sample from $p_t(\mathbf{x})$ by running several steps of Langevin MCMC, replacing $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ with $s_\theta(\mathbf{x}, t)$ in the iteration rule.
#
# Predictor-Corrector samplers combine both numerical solvers for the reverse-time SDE and the Langevin MCMC approach. In particular, we first apply one step of numerical SDE solver to obtain $\mathbf{x}_{t-\Delta t}$ from $\mathbf{x}_t$, which is called the "predictor" step. Next, we apply several steps of Langevin MCMC to refine $\mathbf{x}_t$, such that $\mathbf{x}_t$ becomes a more accurate sample from $p_{t-\Delta t}(\mathbf{x})$. This is the "corrector" step as the MCMC helps reduce the error of the numerical SDE solver.

# %% [markdown]
# ## Sampling with Numerical ODE Solvers
#
# For any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
# there exists an associated ordinary differential equation (ODE)
# \begin{align*}
# d \mathbf{x} = \bigg[\mathbf{f}(\mathbf{x}, t) - \frac{1}{2}g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})\bigg] dt,
# \end{align*}
# such that their trajectories have the same mariginal probability density $p_t(\mathbf{x})$. We call this ODE the *probability flow ODE*.
#
# Therefore, we can start from a sample from $p_T$, integrate the ODE in the reverse time direction, and then get a sample from $p_0 = p_\text{data}$. In particular, for our chosen forward SDE, we can integrate the following SDE from $t=T$ to $0$ for sample generation
# \begin{align*}
# d\mathbf{x} =  -\frac{1}{2}\frac{d[\sigma^2(t)]}{d t} s_\theta(\mathbf{x}, t) dt.
# \end{align*}
# This can be done using many heavily-optimized black-box ODE solvers provided by packages such as `scipy`.

# %%
#@title SDE sampling (double click to expand or collapse)

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def sde_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, device='cuda'):
  """
  Generate samples from score-based models with numerical SDE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x       
    return x

# %%
#@title PC sampling (double click to expand or collapse)

signal_to_noise_ratio = 0.15 #@param {'type':'number'}

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def pc_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, snr=signal_to_noise_ratio, device='cuda'):
  """
  Generate samples from score-based models with Predictor-Corrector method.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      # Corrector step
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x 

      # Predictor step
      grad = score_model(x, batch_time_step)
      grad_norm = torch.norm(grad.reshape(grad.shape[0], -1), dim=-1).mean()
      noise_norm = np.sqrt(np.prod(x.shape[1:]))
      langevin_step_size = 2 * (snr * noise_norm / grad_norm)**2
      x = x + langevin_step_size * grad + torch.sqrt(2 * langevin_step_size) * torch.randn_like(x)      
    return x

# %%
#@title ODE sampling (double click to expand or collapse)

from scipy import integrate

## The error tolerance for the black-box ODE solver
error_tolerance = 1e-5 #@param {'type': 'number'}
def ode_sampler(score_model, noise_scale, batch_size=64, atol=error_tolerance, rtol=error_tolerance, device='cuda', z=None):
  """
  Generate samples from score-based models with black-box ODE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  atol: tolerance of absolute errors.
  rtol: tolerance of relative errors.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  z: the latent code that governs the final sample. If None, we start from p_1;
    otherwise, we start from the given z.
  """
  t = torch.ones(batch_size, device=device)
  # Create the latent code
  if z is None:
    init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  else:
    init_x = z
    
  shape = init_x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper of the score-based model for use by the ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):        
    """The ODE function for use by the ODE solver."""
    time_steps = np.ones((shape[0],)) * t
    
    return  -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(x, time_steps)    
  
  # Run the black-box ODE solver.
  res = integrate.solve_ivp(ode_func, (1., 1e-2), init_x.reshape(-1).cpu().numpy(), rtol=rtol, atol=atol, method='RK45')  
  print(f"Number of function evaluations: {res.nfev}")
  x = torch.tensor(res.y[:, -1], device=device).reshape(shape)

  return x

# %%
#@title Sampling (double click to expand or collapse)

from torchvision.utils import make_grid

## Load the pre-trained checkpoint from disk.
device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}
ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)
sample_batch_size = 64 #@param {'type':'integer'}
sampler = pc_sampler #@param ['sde_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
samples = sampler(score_model, noise_scale_func, sample_batch_size, device=device)

## Sample visualization.
samples = samples.clamp(0.0, 1.0)
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %% [markdown]
# ## Likelihood Computation
#
# A by-product of the probability flow ODE formulation is likelihood computation. Suppose we have a differentiable one-to-one mapping $\mathbf{h}$ that transforms a data sample $\mathbf{x} \sim p_0$ to a prior distribution $\mathbf{h}(\mathbf{x}) \sim p_1$. We can compute the likelihood of $p_0(\mathbf{x})$ via the following [change-of-variable formula](https://en.wikipedia.org/wiki/Probability_density_function#Function_of_random_variables_and_change_of_variables_in_the_probability_density_function)
# \begin{align*}
# p_0(\mathbf{x}) = p_1(\mathbf{h}(\mathbf{x})) |\operatorname{det}(J_\mathbf{h}(\mathbf{x}))|,
# \end{align*}
# where $J_\mathbf{h}(\mathbf{x})$ represents the Jacobian of the mapping $\mathbf{h}$, and we assume it is efficient to evaluate the likelihood of the prior distribution $p_1$.
#
# Similarly, an ODE is also a one-to-one mapping from $\mathbf{x}(0)$ to $\mathbf{x}(1)$. For ODEs of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt,
# \end{align*}
# there exists an [instantaneous change-of-variable formula](https://arxiv.org/abs/1806.07366) that connects the probability of $p_0(\mathbf{x})$ and $p_1(\mathbf{x})$, given by
# \begin{align*}
# p_0 (\mathbf{x}(0)) = e^{\int_0^1 \operatorname{div} \mathbf{f}(\mathbf{x}(t), t) d t} p_1(\mathbf{x}(1)),
# \end{align*}
# where $\operatorname{div}$ denotes the divergence function (trace of Jacobian).
#
# In practice, this divergence function can be hard to evaluate for general vector-valued function $\mathbf{f}$, but we can use an unbiased estimator, named [Skilling-Hutchinson estimator](http://blog.shakirm.com/2015/09/machine-learning-trick-of-the-day-3-hutchinsons-trick/), to approximate the trace. Let $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$. The Skilling-Hutchinson estimator is based on the fact that
# \begin{align*}
# \operatorname{div} \mathbf{f}(\mathbf{x}) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_\mathbf{f}(\mathbf{x}) \boldsymbol\epsilon].
# \end{align*}
# Therefore, we can simply sample a random vector $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, and then use $\boldsymbol \epsilon^\intercal J_\mathbf{f}(\mathbf{x}) \boldsymbol \epsilon$ to estimate the divergence of $\mathbf{f}(\mathbf{x})$. This estimator only requires computing the Jacobian-vector product $J_\mathbf{f}(\mathbf{x})\boldsymbol \epsilon$, which is typically efficient.
#
# As a result, for our probability flow ODE, we can compute the (log) data likelihood with the following
# \begin{align*}
# \log p_0(\mathbf{x}(0)) = \log p_1(\mathbf{x}(1)) -\frac{1}{2}\int_0^1 \frac{d[\sigma^2(t)]}{dt} \operatorname{div} s_\theta(\mathbf{x}(t), t) dt.
# \end{align*}
# With the Skilling-Hutchinson estimator, we can compute the divergence via
# \begin{align*}
# \operatorname{div} s_\theta(\mathbf{x}(t), t) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_{s_\theta}(\mathbf{x}(t), t) \boldsymbol\epsilon].
# \end{align*}
# Afterwards, we can compute the integral with numerical integrators. This gives us an unbiased estimate to the true data likelihood, and we can make it more and more accurate when we run it multiple times and take the average. The numerical integrator requires $\mathbf{x}(t)$ as a function of $t$, which can be obtained by solving the original probability flow ODE.

# %%
#@title Likelihood function (double click to expand or collapse)

def prior_likelihood(z, sigma):
  """The likelihood of a Gaussian distribution with mean zero and 
      standard deviation sigma."""
  shape = z.shape
  N = np.prod(shape[1:])
  return -N / 2. * torch.log(2*np.pi*sigma**2) - torch.sum(z**2, dim=(1,2,3)) / (2 * sigma**2)

def ode_likelihood(x, score_model, noise_scale, batch_size=64, device='cuda'):

  # Draw the random Gaussian sample for Skilling-Hutchinson's estimator.
  epsilon = torch.randn_like(x)
      
  def divergence_eval(sample, time_steps, epsilon):      
    """Compute the divergence of the score-based model with Skilling-Hutchinson."""
    with torch.enable_grad():
      sample.requires_grad_(True)
      score_e = torch.sum(score_model(sample, time_steps) * epsilon)
      grad_score_e = torch.autograd.grad(score_e, sample)[0]
    return torch.sum(grad_score_e * epsilon, dim=(1, 2, 3))    
  
  shape = x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the score-based model for the black-box ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def divergence_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the divergence of score for the black-box ODE solver."""
    with torch.no_grad():
      # Obtain x(t) by solving the probability flow ODE.
      sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
      time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
      # Compute likelihood.
      div = divergence_eval(sample, time_steps, epsilon)
      return div.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):
    """The ODE function for the black-box solver."""
    time_steps = np.ones((shape[0],)) * t    
    sample = x[:-shape[0]]
    logp = x[-shape[0]:]
    sample_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(sample, time_steps)
    logp_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * divergence_eval_wrapper(sample, time_steps)
    return np.concatenate([sample_grad, logp_grad], axis=0)

  init = np.concatenate([x.cpu().numpy().reshape((-1,)), np.zeros((shape[0],))], axis=0)
  # Black-box ODE solver
  res = integrate.solve_ivp(ode_func, (1e-3, 1.), init, rtol=1e-5, atol=1e-5, method='RK45')  
  zp = torch.tensor(res.y[:, -1], device=device)
  z = zp[:-shape[0]].reshape(shape)
  delta_logp = zp[-shape[0]:].reshape(shape[0])
  sigma_max = noise_scale(torch.ones((), device=device))[0]
  prior_logp = prior_likelihood(z, sigma_max)
  bpd = -(prior_logp + delta_logp) / np.log(2)
  N = np.prod(shape[1:])
  bpd = bpd / N + 8.
  return z, bpd

# %%
#@title Computing likelihood on the dataset (double click to expand or collapse)

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)

all_bpds = 0.
all_items = 0
try:
  for x, _ in tqdm.notebook.tqdm(data_loader):
    x = x.to(device)
    # uniform dequantization
    x = (x * 255. + torch.rand_like(x)) / 256.    
    _, bpd = ode_likelihood(x, score_model, noise_scale_func, x.shape[0], device=device)
    all_bpds += bpd.sum()
    all_items += bpd.shape[0]
    print(f"bpd (running average): {all_bpds / all_items}")
  print(f"bpd (full average): {all_bpds/all_items}")
except KeyboardInterrupt:
  # Remove the error message when interuptted by keyboard or GUI.
  pass
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# bpd (running average): 2.25548265175453
# bpd (running average): 2.227481821491158
# bpd (running average): 2.2303003996805
# bpd (running average): 2.2081874680508347
# bpd (running average): 2.248593453020829
# bpd (running average): 2.2178476316662703
# bpd (running average): 2.202320923893052
# bpd (running average): 2.224204365356273
# bpd (running average): 2.2280903091885773
# bpd (running average): 2.218715058275438
# bpd (running average): 2.2298148983077684
# bpd (running average): 2.250336600923667
# bpd (running average): 2.26108732084572
# bpd (running average): 2.245358348269535
# bpd (running average): 2.2516615224134418
# bpd (running average): 2.2613291022478847
# bpd (running average): 2.264402051904375
# bpd (running average): 2.253784667149083
# bpd (running average): 2.2456954875257704
# bpd (running average): 2.2444021489144332
# bpd (running average): 2.238450138164762
# bpd (running average): 2.2347850563250478
# bpd (running average): 2.238993148067161
# bpd (running average): 2.244150113762065
# bpd (running average): 2.2436727616974093
# bpd (running average): 2.230712278727939
# bpd (running average): 2.2336281095195596
# bpd (running average): 2.2281428931190606
# bpd (running average): 2.226290540436898
# bpd (running average): 2.2282052235837737
# bpd (running average): 2.2328669414249207
# bpd (running average): 2.2303234578442854
# bpd (running average): 2.229884964672698
# bpd (running average): 2.2242381958284647
# bpd (running average): 2.2294595522840717
# bpd (running average): 2.225778011983319
# bpd (running average): 2.2275201119749055
# bpd (running average): 2.229211766307233
# bpd (running average): 2.2288465270397766
# bpd (running average): 2.230329379366498
# bpd (running average): 2.23401893190874
# bpd (running average): 2.2300574882688062
# bpd (running average): 2.2287942747421923
# bpd (running average): 2.2362594024406883
# bpd (running average): 2.235162428126134
# bpd (running average): 2.233763295150981
# bpd (running average): 2.235192489836444
# bpd (running average): 2.2357810457615477
# bpd (running average): 2.2359364375061483
# bpd (running average): 2.2334623015208437
# bpd (running average): 2.2317447030425104
# bpd (running average): 2.229135865672042
# bpd (running average): 2.2276263939483716
# bpd (running average): 2.2236026247036036
# bpd (running average): 2.22263956708275
# bpd (running average): 2.2201806906769526
# bpd (running average): 2.2219798914305833
# bpd (running average): 2.220211717037146
# bpd (running average): 2.21795076707155
# bpd (running average): 2.220878399609469
# bpd (running average): 2.223262986944269
# bpd (running average): 2.223892742827331
# bpd (running average): 2.2265715711408895
# bpd (running average): 2.2235398430885382
# bpd (running average): 2.222399467667717
# bpd (running average): 2.2209532574162427
# bpd (running average): 2.223175133942626
# bpd (running average): 2.223373985434469
# bpd (running average): 2.2225013352207643
# bpd (running average): 2.222700156852858
# bpd (running average): 2.2225476844112366
# bpd (running average): 2.2229188747639474
# bpd (running average): 2.2242641612968828
# bpd (running average): 2.2238572645985477
# bpd (running average): 2.2260574433351525
# bpd (running average): 2.2251995520261074
# bpd (running average): 2.227504391243286
# bpd (running average): 2.229356909879094
# bpd (running average): 2.228106052004417
# bpd (running average): 2.2313192920018396
# bpd (running average): 2.2310735457479023
# bpd (running average): 2.2291863825447313
# bpd (running average): 2.231363586248354
# bpd (running average): 2.22699718192222
# bpd (running average): 2.2237373432227914
# bpd (running average): 2.2219704879088957
# bpd (running average): 2.2232762574712504
# bpd (running average): 2.224785179571882
# bpd (running average): 2.222999479266579
# bpd (running average): 2.2231308414845032
# bpd (running average): 2.2232482041680206
# bpd (running average): 2.221710689014407
# bpd (running average): 2.220342037819595
# bpd (running average): 2.219592552478548
# bpd (running average): 2.2201843741559313
# bpd (running average): 2.221443623993531
# bpd (running average): 2.2222958859900532
# bpd (running average): 2.2208318780669676
# bpd (running average): 2.219299717362531
# bpd (running average): 2.2205852690692955
# bpd (running average): 2.2215699336829426
# bpd (running average): 2.2232725714303845
# bpd (running average): 2.2243105090904844
# bpd (running average): 2.225327329293487
# bpd (running average): 2.2252895030229354
# bpd (running average): 2.223442155007416
# bpd (running average): 2.2227054053227366
# bpd (running average): 2.222615713644544
# bpd (running average): 2.2229401359532983
# bpd (running average): 2.22253276199321
# bpd (running average): 2.2239461317661466
# bpd (running average): 2.2236452836890024
# bpd (running average): 2.2246163281239495
# bpd (running average): 2.2240771590709856
# bpd (running average): 2.22489572244693
# bpd (running average): 2.2261352544725868
# bpd (running average): 2.225654159883324
# bpd (running average): 2.223982170091258
# bpd (running average): 2.221940738044104
# bpd (running average): 2.2221128038444125
# bpd (running average): 2.220711843899583
# bpd (running average): 2.221418534994734
# bpd (running average): 2.2208687056961804
# bpd (running average): 2.2212357560113865
# bpd (running average): 2.221964666769253
# bpd (running average): 2.222477145923222
# bpd (running average): 2.2205539705244144
# bpd (running average): 2.220645004789808
# bpd (running average): 2.2196778629239953
# bpd (running average): 2.221228158611672
# bpd (running average): 2.221136149381998
# bpd (running average): 2.2232608695137315
# bpd (running average): 2.2225380515355813
# bpd (running average): 2.222120152195383
# bpd (running average): 2.223380041943417
# bpd (running average): 2.2223544369559494
# bpd (running average): 2.2218643344270976
# bpd (running average): 2.2218457506566582
# bpd (running average): 2.2218460402628124
# bpd (running average): 2.221647906710129
# bpd (running average): 2.2223749544490343
# bpd (running average): 2.2236139770104986
# bpd (running average): 2.223223325689642
# bpd (running average): 2.225556873996
# bpd (running average): 2.224630743413788
# bpd (running average): 2.224393959089038
# bpd (running average): 2.2247222069409562
# bpd (running average): 2.2246199097721635
# bpd (running average): 2.2242806856681163
# bpd (running average): 2.224624665331328
# bpd (running average): 2.2243176370272315
# bpd (running average): 2.224975855381315
# bpd (running average): 2.226675221792522
# bpd (running average): 2.2263037040640365
# bpd (running average): 2.2263116314999167
# bpd (running average): 2.224088833058767
# bpd (running average): 2.2240764909162114
# bpd (running average): 2.223068259740234
# bpd (running average): 2.2254830936473784
# bpd (running average): 2.2253864031684762
# bpd (running average): 2.224939864810954
# bpd (running average): 2.2250199458392985
# bpd (running average): 2.223832082748054
# bpd (running average): 2.223268721984101
# bpd (running average): 2.2240482262205874
# bpd (running average): 2.225538116649111
# bpd (running average): 2.2251720847289267
# bpd (running average): 2.2249133024196346
# bpd (running average): 2.2255076996780656
# bpd (running average): 2.2253902228897506
# bpd (running average): 2.2251407176450635
# bpd (running average): 2.225349831152743
# bpd (running average): 2.2257030652576337
# bpd (running average): 2.2244401994697203
# bpd (running average): 2.2252572642622686
# bpd (running average): 2.226182561499881
# bpd (running average): 2.227664893679158
# bpd (running average): 2.2280386545018
# bpd (running average): 2.2284876897960633
# bpd (running average): 2.2282775069910747
# bpd (running average): 2.2278394518747477
# bpd (running average): 2.2284798094063607
# bpd (running average): 2.2281160476400954
# bpd (running average): 2.2270057132775274
# bpd (running average): 2.2266625262709714
# bpd (running average): 2.227955812992601
# bpd (running average): 2.227799238763963
# bpd (running average): 2.2277513708448167
# bpd (running average): 2.2283475531276156
# bpd (running average): 2.2289742821803253
# bpd (running average): 2.2289829617029038
# bpd (running average): 2.2293821273518444
# bpd (running average): 2.2302225909948894
# bpd (running average): 2.23084811641775
# bpd (running average): 2.2302773783211505
# bpd (running average): 2.230063037778306
# bpd (running average): 2.2294866072498896
# bpd (running average): 2.230310327472768
# bpd (running average): 2.2299853497715074
# bpd (running average): 2.2312864014016442
# bpd (running average): 2.2322277070928815
# bpd (running average): 2.2324792078542264
# bpd (running average): 2.232256134396149
# bpd (running average): 2.2315350115953145
# bpd (running average): 2.231210933512087
# bpd (running average): 2.231851512321758
# bpd (running average): 2.2326645186232796
# bpd (running average): 2.232322570407439
# bpd (running average): 2.2324962831272104
# bpd (running average): 2.2325393718087128
# bpd (running average): 2.232321848549462
# bpd (running average): 2.2322360254996383
# bpd (running average): 2.2322521951495693
# bpd (running average): 2.2321257240977603
# bpd (running average): 2.2315471209655295
# bpd (running average): 2.2312413915197604
# bpd (running average): 2.230875702002629
# bpd (running average): 2.2301823291052685
# bpd (running average): 2.229656723868545
# bpd (running average): 2.2291760843664314
# bpd (running average): 2.2295219093966248
# bpd (running average): 2.2299630192618562
# bpd (running average): 2.230261302894478
# bpd (running average): 2.2309354045337364
# bpd (running average): 2.231214472181093
# bpd (running average): 2.2311071603100956
# bpd (running average): 2.230586504699344
# bpd (running average): 2.231376471783348
# bpd (running average): 2.230936213628977
# bpd (running average): 2.231465844072634
# bpd (running average): 2.2319799414789117
# bpd (running average): 2.2312627979709134
# bpd (running average): 2.2318694445782477
# bpd (running average): 2.231705957539673
# bpd (running average): 2.2326965480863925
# bpd (running average): 2.2325271203383004
# bpd (running average): 2.2321101164336854
# bpd (running average): 2.2328787093927187
# bpd (running average): 2.2326355036956387
# bpd (running average): 2.2324320624539467
# bpd (running average): 2.2330001256287075
# bpd (running average): 2.232842843942791
# bpd (running average): 2.2323900868595996
# bpd (running average): 2.232623904936613
# bpd (running average): 2.232851166489239
# bpd (running average): 2.233173538759086
# bpd (running average): 2.2338225907645213
# bpd (running average): 2.234017840894813
# bpd (running average): 2.2345960962379254
# bpd (running average): 2.234806929407017
# bpd (running average): 2.234639057591227
# bpd (running average): 2.233999544331989
# bpd (running average): 2.2338293445652093
# bpd (running average): 2.233751902087963
# bpd (running average): 2.2335126523857514
# bpd (running average): 2.2331540099947924
# bpd (running average): 2.2326764825871663
# bpd (running average): 2.2320711356077667
# bpd (running average): 2.2311807710248717
# bpd (running average): 2.2316957814831597
# bpd (running average): 2.2316494687299393
# bpd (running average): 2.231859923849708
# bpd (running average): 2.232125847643967
# bpd (running average): 2.2314256352167376
# bpd (running average): 2.232238209223926
# bpd (running average): 2.2322819943827215
# bpd (running average): 2.2322493274908877
# bpd (running average): 2.231539139411689
# bpd (running average): 2.2314619057220173
# bpd (running average): 2.231729503273644
# bpd (running average): 2.2315263427185075
# bpd (running average): 2.2324179076634194
# bpd (running average): 2.23202344151079
# bpd (running average): 2.231860332483824
# bpd (running average): 2.230823228890692
# bpd (running average): 2.2305864128623405
# bpd (running average): 2.230222766944203
# bpd (running average): 2.2307138886446327
# bpd (running average): 2.230591141701034
# bpd (running average): 2.2306304182305623
# bpd (running average): 2.231262089921655
# bpd (running average): 2.2312282525537097
# bpd (running average): 2.2314606288128154
# bpd (running average): 2.2307608052068923
# bpd (running average): 2.232015505355052
# bpd (running average): 2.232281751201887
# bpd (running average): 2.2324573643630585
# bpd (running average): 2.2317969089846303
# bpd (running average): 2.2317189343016484
# bpd (running average): 2.2318836648191165
# bpd (running average): 2.232381444258282
# bpd (running average): 2.23264342209075
# bpd (running average): 2.2324340122038464
# bpd (running average): 2.231854818151435
# bpd (running average): 2.2313088318926932
# bpd (running average): 2.231279400856421
# bpd (running average): 2.2312943065226962
# bpd (running average): 2.2304242141161237
# bpd (running average): 2.2304846251702575
# bpd (running average): 2.2308851509212344
# bpd (running average): 2.230599625084509
# bpd (running average): 2.231115591057656
# bpd (running average): 2.231731826290625
# bpd (running average): 2.2319928478752042
# bpd (running average): 2.2323035970155205
# bpd (running average): 2.231847196754232
# bpd (running average): 2.231735754029797
# bpd (running average): 2.2313340216320774
# bpd (running average): 2.231062405334392
# bpd (running average): 2.2312515447859163
# bpd (running average): 2.2313275148537444
# bpd (running average): 2.2310281442908932
# bpd (running average): 2.2310313918396143
# bpd (running average): 2.2314750554473384
# bpd (running average): 2.2313480860517556
# bpd (running average): 2.231633745628438
# bpd (running average): 2.231697806262435
# bpd (running average): 2.232139198707046
# bpd (running average): 2.2320641596231083
# bpd (running average): 2.232008828642972
# bpd (running average): 2.2322496773413034
# bpd (running average): 2.232376840342999
# bpd (running average): 2.2326982406695812
# bpd (running average): 2.232807729990208
# bpd (running average): 2.232618974667427
# bpd (running average): 2.2331464421572087
# bpd (running average): 2.2333617692914443
# bpd (running average): 2.233806429730503
# bpd (running average): 2.2340156223311034
# bpd (running average): 2.2329370925538505
# bpd (running average): 2.233247959870836
# bpd (running average): 2.23335265334881
# bpd (running average): 2.233743092673818
# bpd (running average): 2.234012156032414
# bpd (running average): 2.234025840724749
# bpd (running average): 2.233993580278151
# bpd (running average): 2.2336097369806747
# bpd (running average): 2.2333307242833444
# bpd (running average): 2.2329466018406485
# bpd (running average): 2.2323422079900683
# bpd (running average): 2.2329953570903873
# bpd (running average): 2.2322107607428947
# bpd (running average): 2.232417018367467
# bpd (running average): 2.232057563530953
# bpd (running average): 2.2325963871752488
# bpd (running average): 2.2323481027652647
# bpd (running average): 2.232458565545193
# bpd (running average): 2.232545527153485
# bpd (running average): 2.2325969404511823
# bpd (running average): 2.233012131703388
# bpd (running average): 2.233309577125104
# bpd (running average): 2.233520025006751
# bpd (running average): 2.233363005613672
# bpd (running average): 2.2337288179476222
# bpd (running average): 2.2336620832357426
# bpd (running average): 2.233995472162754
# bpd (running average): 2.2337921488914687
# bpd (running average): 2.2340384242212514
# bpd (running average): 2.2342021144851523
# bpd (running average): 2.2344777283967576
# bpd (running average): 2.2352177497537786
# bpd (running average): 2.2354403391283197
# bpd (running average): 2.235068062959707
# bpd (running average): 2.234954513453208
# bpd (running average): 2.2347330879107097
# bpd (running average): 2.2344885849720986
# bpd (running average): 2.2351094180899427
# bpd (running average): 2.235284547136246
# bpd (running average): 2.2355501804586395
# bpd (running average): 2.236021253585218
# bpd (running average): 2.2356633838328146
# bpd (running average): 2.236191807293783
# bpd (running average): 2.235832560175269
# bpd (running average): 2.2355582957549376
# bpd (running average): 2.2354873373633564
# bpd (running average): 2.2359048076990398
# bpd (running average): 2.2360861539482904
# bpd (running average): 2.2361480879286644
# bpd (running average): 2.2362356674457136
# bpd (running average): 2.2366212468937956
# bpd (running average): 2.236121388952814
# bpd (running average): 2.236408414195774
# bpd (running average): 2.236389839192549
# bpd (running average): 2.237068369506912
# bpd (running average): 2.2370679868783845
# bpd (running average): 2.236788431735807
# bpd (running average): 2.236813109860213
# bpd (running average): 2.237075065389677
# bpd (running average): 2.2367967811337386
# bpd (running average): 2.2365245584453803
# bpd (running average): 2.237076193755479
# bpd (running average): 2.2372563166192476
# bpd (running average): 2.2376574672582024
# bpd (running average): 2.2379965337380736
# bpd (running average): 2.238344554676482
# bpd (running average): 2.238716981971261
# bpd (running average): 2.2385560803136912
# bpd (running average): 2.238878487367364
# bpd (running average): 2.239432942865585
# bpd (running average): 2.2391633370866435
# bpd (running average): 2.2392603619657754
# bpd (running average): 2.2387490434901482
# bpd (running average): 2.2394605282589
# bpd (running average): 2.2391536865697197
# bpd (running average): 2.239140732637059
# bpd (running average): 2.2394904156517965
# bpd (running average): 2.239662950698809
# bpd (running average): 2.239748978521414
# bpd (running average): 2.2401265208135226
# bpd (running average): 2.239647045077064
# bpd (running average): 2.2390266263430534
# bpd (running average): 2.2393542375108884
# bpd (running average): 2.2400273759422613
# bpd (running average): 2.2403164979902868
# bpd (running average): 2.2403929682516694
# bpd (running average): 2.241106250277549
# bpd (running average): 2.240999776126105
# bpd (running average): 2.2410088074925136
# bpd (running average): 2.2410614205953863
# bpd (running average): 2.241192848837255
# bpd (running average): 2.241230628557635
# bpd (running average): 2.2414739993371464
# bpd (running average): 2.2414638959366804
# bpd (running average): 2.241180964120102
# bpd (running average): 2.241155745254889
# bpd (running average): 2.240979668933731
# bpd (running average): 2.2411220613393454
# bpd (running average): 2.2405505630466442
# bpd (running average): 2.2407539565985637
# bpd (running average): 2.240435171517198
# bpd (running average): 2.240444992018259
# bpd (running average): 2.2401970809122873
# bpd (running average): 2.240191747782382
# bpd (running average): 2.239944091412249
# bpd (running average): 2.2399316689067192
# bpd (running average): 2.2399556338671984
# bpd (running average): 2.239462542870364
# bpd (running average): 2.2395992068969184
# bpd (running average): 2.2398023676427252
# bpd (running average): 2.2400512859023185
# bpd (running average): 2.2402960509470855
# bpd (running average): 2.240621752692465
# bpd (running average): 2.2409975361781265
# bpd (running average): 2.2402926755085835
# bpd (running average): 2.240334279737393
# bpd (running average): 2.2403464774839312
# bpd (running average): 2.240018111032402
# bpd (running average): 2.239906105443374
# bpd (running average): 2.2404630254723243
# bpd (running average): 2.2411805688123128
# bpd (running average): 2.2412527549638686
# bpd (running average): 2.241095090289308
# bpd (running average): 2.241122318158116
# bpd (running average): 2.240707058917292
# bpd (running average): 2.2409331368548675
# bpd (running average): 2.240747531227583
# bpd (running average): 2.2407803364413907
# bpd (running average): 2.2404568685263193
# bpd (running average): 2.240599289972513
# bpd (running average): 2.2401652057386148
# bpd (running average): 2.240295362846974
# bpd (running average): 2.239829543813202
# bpd (running average): 2.239345836191353
# bpd (running average): 2.239375880170531
# bpd (running average): 2.239292123465055
# bpd (running average): 2.2397351158382364
# bpd (running average): 2.2398242770430676
# bpd (running average): 2.240035936326948
# bpd (running average): 2.2399619562754514
# bpd (running average): 2.239469990376901
# bpd (running average): 2.239393957439545
# bpd (running average): 2.239258163606398
# bpd (running average): 2.2392305028133017
# bpd (running average): 2.239156498513584
# bpd (running average): 2.2387874703994624
# bpd (running average): 2.238532352226175
# bpd (running average): 2.2387078736943695
# bpd (running average): 2.2388964791617356
# bpd (running average): 2.238649851903667
# bpd (running average): 2.238112891591742
# bpd (running average): 2.2377884001171435
# bpd (running average): 2.2377407004061234
# bpd (running average): 2.237604161261974
# bpd (running average): 2.237390390996206
# bpd (running average): 2.2369862514218966
# bpd (running average): 2.2368519918036025
# bpd (running average): 2.2365988201494087
# bpd (running average): 2.2363752511714567
# bpd (running average): 2.236819473770348
# bpd (running average): 2.2367884866558034
# bpd (running average): 2.236886092739005
# bpd (running average): 2.2362715755693907
# bpd (running average): 2.235763564605589
# bpd (running average): 2.2357326704735865
# bpd (running average): 2.2356314428851056
# bpd (running average): 2.235401960911568
# bpd (running average): 2.235650506494707
# bpd (running average): 2.235401103781041
# bpd (running average): 2.2355894154137737
# bpd (running average): 2.235478295171769
# bpd (running average): 2.2355533925121227
# bpd (running average): 2.235655454895089
# bpd (running average): 2.2352799161856725
# bpd (running average): 2.23550838088939
# bpd (running average): 2.235392339295097
# bpd (running average): 2.235937575303872
# bpd (running average): 2.2359227298220303
# bpd (running average): 2.235856869431152
# bpd (running average): 2.235807899501665
# bpd (running average): 2.2362022611682564
# bpd (running average): 2.236219285262077
# bpd (running average): 2.2361681860373697
# bpd (running average): 2.2360733376852067
# bpd (running average): 2.2359427735146515
# bpd (running average): 2.235767106989282
# bpd (running average): 2.2359362335271893
# bpd (running average): 2.235833350591569
# bpd (running average): 2.235806370486316
# bpd (running average): 2.235930798802369
# bpd (running average): 2.23606252759807
# bpd (running average): 2.2358896227755523
# bpd (running average): 2.236169141655327
# bpd (running average): 2.2359053004719125
# bpd (running average): 2.2360420691117016
# bpd (running average): 2.236051993076369
# bpd (running average): 2.2362728648519226
# bpd (running average): 2.235976881520515
# bpd (running average): 2.2360140097147223
# bpd (running average): 2.2357337447162156
# bpd (running average): 2.2354436467161265
# bpd (running average): 2.23562614284539
# bpd (running average): 2.236012891665487
# bpd (running average): 2.2358642090379535
# bpd (running average): 2.2356595397134362
# bpd (running average): 2.2354906591452397
# bpd (running average): 2.235901926601116
# bpd (running average): 2.2360180756858408
# bpd (running average): 2.23621077078135
# bpd (running average): 2.2360468435560814
# bpd (running average): 2.236085085389571
# bpd (running average): 2.2360808595938777
# bpd (running average): 2.2363876300938177
# bpd (running average): 2.2362591203818423
# bpd (running average): 2.236121346274814
# bpd (running average): 2.236062907155768
# bpd (running average): 2.236151751077123
# bpd (running average): 2.2362288939928314
# bpd (running average): 2.2360234195847197
# bpd (running average): 2.2360751289057075
# bpd (running average): 2.23608577636303
# bpd (running average): 2.236112736632485
# bpd (running average): 2.2357463918635436
# bpd (running average): 2.2358104963846612
# bpd (running average): 2.235883145340567
# bpd (running average): 2.2361413178464633
# bpd (running average): 2.23613920595945
# bpd (running average): 2.235779321754804
# bpd (running average): 2.2358265962215396
# bpd (running average): 2.2359782747793795
# bpd (running average): 2.2359266965089692
# bpd (running average): 2.235828104008925
# bpd (running average): 2.2356470888826383
# bpd (running average): 2.2355826664558687
# bpd (running average): 2.235576292733724
# bpd (running average): 2.2360581393709285
# bpd (running average): 2.2358679829758263
# bpd (running average): 2.235816410428642
# bpd (running average): 2.235615838520575
# bpd (running average): 2.2355882765595867
# bpd (running average): 2.235720649024101
# bpd (running average): 2.2357916927583994
# bpd (running average): 2.2360939026532516
# bpd (running average): 2.2361774814365294
# bpd (running average): 2.2363951791391132
# bpd (running average): 2.2365444555398133
# bpd (running average): 2.236615941186992
# bpd (running average): 2.236738082773762
# bpd (running average): 2.236675365046117
# bpd (running average): 2.236658872106392
# bpd (running average): 2.2365610943519574
# bpd (running average): 2.2367043831896707
# bpd (running average): 2.2369588548136847
# bpd (running average): 2.2367292649934205
# bpd (running average): 2.236605943794164
# bpd (running average): 2.2365905828280557
# bpd (running average): 2.236957343213984
# bpd (running average): 2.2368026705722444
# bpd (running average): 2.236549740696532
# bpd (running average): 2.237054489673683
# bpd (running average): 2.2368377710200615
# bpd (running average): 2.2367240595647973
# bpd (running average): 2.236504285169868
# bpd (running average): 2.237187390574288
# bpd (running average): 2.237386055491837
# bpd (running average): 2.237570140693978
# bpd (running average): 2.2377093562613544
# bpd (running average): 2.237641893659391
# bpd (running average): 2.2377334582142065
# bpd (running average): 2.2379303936054136
# bpd (running average): 2.238337100807538
# bpd (running average): 2.238233116422535
# bpd (running average): 2.2383069554126456
# bpd (running average): 2.2380650360150907
# bpd (running average): 2.237924858280335
# bpd (running average): 2.238425120484381
# bpd (running average): 2.2384886929892085
# bpd (running average): 2.2384264589560243
# bpd (running average): 2.2384562602634643
# bpd (running average): 2.2387465031492746
# bpd (running average): 2.238494514328452
# bpd (running average): 2.238776936380745
# bpd (running average): 2.2388617682421987
# bpd (running average): 2.238912445430119
# bpd (running average): 2.2388102633009184
# bpd (running average): 2.2391323251717536
# bpd (running average): 2.239420533003386
# bpd (running average): 2.2397180328125335
# bpd (running average): 2.239672966657539
# bpd (running average): 2.2394966635931515
# bpd (running average): 2.239650561479808
# bpd (running average): 2.2398928348225224
# bpd (running average): 2.23968639389589
# bpd (running average): 2.239641136757545
# bpd (running average): 2.2394753259648668
# bpd (running average): 2.239551962208057
# bpd (running average): 2.2395464244807686
# bpd (running average): 2.239397076010101
# bpd (running average): 2.2394657370324293
# bpd (running average): 2.2396159665427504
# bpd (running average): 2.2396424499116296
# bpd (running average): 2.2396281624492276
# bpd (running average): 2.2398037348890223
# bpd (running average): 2.239846228569512
# bpd (running average): 2.239668460422647
# bpd (running average): 2.239679671991668
# bpd (running average): 2.239891554398856
# bpd (running average): 2.239477067557851
# bpd (running average): 2.2394716438055022
# bpd (running average): 2.2392295518452423
# bpd (running average): 2.2391424108327134
# bpd (running average): 2.2391686579053136
# bpd (running average): 2.2392073445419567
# bpd (running average): 2.2393992073959637
# bpd (running average): 2.239773680375387
# bpd (running average): 2.2393772600878967
# bpd (running average): 2.239038439639044
# bpd (running average): 2.2390711203537887
# bpd (running average): 2.2391424932618076
# bpd (running average): 2.2395613168549824
# bpd (running average): 2.2393827576539307
# bpd (running average): 2.239336810142371
# bpd (running average): 2.239364450305565
# bpd (running average): 2.2394605422721776
# bpd (running average): 2.2392697662815055
# bpd (running average): 2.2393307056190026
# bpd (running average): 2.2393535648020726
# bpd (running average): 2.2394206087733775
# bpd (running average): 2.2395975777788837
# bpd (running average): 2.239573306494301
# bpd (running average): 2.239468238464347
# bpd (running average): 2.239256240829708
# bpd (running average): 2.239623248046937
# bpd (running average): 2.2394167133442457
# bpd (running average): 2.2392319375337633
# bpd (running average): 2.2394516889435905
# bpd (running average): 2.2393528309610726
# bpd (running average): 2.239532043662567
# bpd (running average): 2.239664037057423
# bpd (running average): 2.2396275044199916
# bpd (running average): 2.239629612049257
# bpd (running average): 2.2398249435220365
# bpd (running average): 2.2400485272564925
# bpd (running average): 2.239909790276501
# bpd (running average): 2.2400737586922954
# bpd (running average): 2.2401554049139545
# bpd (running average): 2.2406719362458962
# bpd (running average): 2.2410533442070615
# bpd (running average): 2.2406861019623094
# bpd (running average): 2.2406977431122383
# bpd (running average): 2.2406146760751606
# bpd (running average): 2.240711503520097
# bpd (running average): 2.2406032735745782
# bpd (running average): 2.240691442864105
# bpd (running average): 2.2405741794047405
# bpd (running average): 2.240781209219478
# bpd (running average): 2.240651913203768
# bpd (running average): 2.2405099692574306
# bpd (running average): 2.2403378590009475
# bpd (running average): 2.240261381478496
# bpd (running average): 2.2405269564394823
# bpd (running average): 2.2407168530972275
# bpd (running average): 2.2403952753516307
# bpd (running average): 2.240353874769173
# bpd (running average): 2.240303394882676
# bpd (running average): 2.2402097734058186
# bpd (running average): 2.240350405416312
# bpd (running average): 2.2402142100158913
# bpd (running average): 2.2400198744214546
# bpd (running average): 2.240423968103909
# bpd (running average): 2.2400858449597365
# bpd (running average): 2.240387641331044
# bpd (running average): 2.24033022000216
# bpd (running average): 2.2402591689112974
# bpd (running average): 2.240075274092774
# bpd (running average): 2.239977547787065
# bpd (running average): 2.23974236019626
# bpd (running average): 2.239960013998208
# bpd (running average): 2.240236038105976
# bpd (running average): 2.240037510102493
# bpd (running average): 2.2397128146811354
# bpd (running average): 2.2399697336429547
# bpd (running average): 2.240050269630787
# bpd (running average): 2.239876168618907
# bpd (running average): 2.2397097637785346
# bpd (running average): 2.23977085171307
# bpd (running average): 2.2395591629157137
# bpd (running average): 2.2395517932946913
# bpd (running average): 2.2394536894334585
# bpd (running average): 2.2397493919098674
# bpd (running average): 2.239713229239604
# bpd (running average): 2.239883568336294
# bpd (running average): 2.239991272388525
# bpd (running average): 2.240049322329334
# bpd (running average): 2.240288895612285
# bpd (running average): 2.240320874449832
# bpd (running average): 2.2402961183179224
# bpd (running average): 2.2404610669666503
# bpd (running average): 2.2405252121269994
# bpd (running average): 2.2405731776794333
# bpd (running average): 2.2407287233536026
# bpd (running average): 2.240605810314436
# bpd (running average): 2.2406962977812674
# bpd (running average): 2.2408596299276127
# bpd (running average): 2.2408890804371935
# bpd (running average): 2.2410125082894115
# bpd (running average): 2.241124786931484
# bpd (running average): 2.2409144047481853
# bpd (running average): 2.2407397457422067
# bpd (running average): 2.240505962961926
# bpd (running average): 2.240368737925286
# bpd (running average): 2.2404998103372744
# bpd (running average): 2.240533776496086
# bpd (running average): 2.2405793212980485
# bpd (running average): 2.2403978240223004
# bpd (running average): 2.2402822323922496
# bpd (running average): 2.240058012649721
# bpd (running average): 2.240065397042285
# bpd (running average): 2.2403637156591523
# bpd (running average): 2.2404065005282887
# bpd (running average): 2.240425912187061
# bpd (running average): 2.240384030775592
# bpd (running average): 2.24012004854187
# bpd (running average): 2.2401203620181476
# bpd (running average): 2.240292047202622
# bpd (running average): 2.240321375106632
# bpd (running average): 2.240590980316734
# bpd (running average): 2.240571996424344
# bpd (running average): 2.2405905056065807
# bpd (running average): 2.2406811813049434
# bpd (running average): 2.2404593888577184
# bpd (running average): 2.2406521015113334
# bpd (running average): 2.2408442215875732
# bpd (running average): 2.240715101028814
# bpd (running average): 2.2406642723619754
# bpd (running average): 2.240591489832725
# bpd (running average): 2.240430818742955
# bpd (running average): 2.24039641288237
# bpd (running average): 2.2403358040211936
# bpd (running average): 2.2403125860141384
# bpd (running average): 2.2399907927685856
# bpd (running average): 2.2401091040956005
# bpd (running average): 2.2400433991277526
# bpd (running average): 2.2399347810530683
# bpd (running average): 2.2397923547641523
# bpd (running average): 2.239947347770067
# bpd (running average): 2.2400232402348927
# bpd (running average): 2.239925214222549
# bpd (running average): 2.2399219668773585
# bpd (running average): 2.239943724209588
# bpd (running average): 2.239690710330065
# bpd (running average): 2.2398034212617053
# bpd (running average): 2.2396611219162548
# bpd (running average): 2.239618316959822
# bpd (running average): 2.239876776764659
# bpd (running average): 2.239911164432857
# bpd (running average): 2.2399452493827647
# bpd (running average): 2.2399613203342925
# bpd (running average): 2.239462417674781
# bpd (running average): 2.2398162979326677
# bpd (running average): 2.2396258699912854
# bpd (running average): 2.2395978836676553
# bpd (running average): 2.2397835724228394
# bpd (running average): 2.239685384735909
# bpd (running average): 2.2398313577808007
# bpd (running average): 2.239876047433097
# bpd (running average): 2.240086017887048
# bpd (running average): 2.2400768484117677
# bpd (running average): 2.2399471778551607
# bpd (running average): 2.2399337440527227
# bpd (running average): 2.2398560043725575
# bpd (running average): 2.2399301791808823
# bpd (running average): 2.2400234051596684
# bpd (running average): 2.2397499674863686
# bpd (running average): 2.23941256448093
# bpd (running average): 2.239596215050814
# bpd (running average): 2.2393292770557047
# bpd (running average): 2.2392182250721664
# bpd (running average): 2.2393095830977847
# bpd (running average): 2.239531956642684
# bpd (running average): 2.239584460956374
# bpd (running average): 2.2397350798378426
# bpd (running average): 2.2392910975722775
# bpd (running average): 2.239335866947485
# bpd (running average): 2.2395035353492387
# bpd (running average): 2.2394243655966286
# bpd (running average): 2.2395642555053046
# bpd (running average): 2.239838503313836
# bpd (running average): 2.2398453110394723
# bpd (running average): 2.2398165095672264
# bpd (running average): 2.2398809092470464
# bpd (running average): 2.2399664251469535
# bpd (running average): 2.2399622906409236
# bpd (running average): 2.239791865205949
# bpd (running average): 2.239580360516139
# bpd (running average): 2.2395526611744927
# bpd (running average): 2.239743582367543
# bpd (running average): 2.2400124229750036
# bpd (running average): 2.2397835910616903
# bpd (running average): 2.239642981008376
# bpd (running average): 2.239850237024379
# bpd (running average): 2.2399016299279433
# bpd (running average): 2.2397812253215177
# bpd (running average): 2.239793488198962
# bpd (running average): 2.239937086592517
# bpd (running average): 2.239906530747616
# bpd (running average): 2.239688691874657
# bpd (running average): 2.2395113873338395
# bpd (running average): 2.2393920396569165
# bpd (running average): 2.2391599989074584
# bpd (running average): 2.239147143422085
# bpd (running average): 2.239232441094597
# bpd (running average): 2.239261452426137
# bpd (running average): 2.239354543684247
# bpd (running average): 2.2393774307582373
# bpd (running average): 2.2392671191506412
# bpd (running average): 2.2390085747140174
# bpd (running average): 2.2387062135483107
# bpd (running average): 2.2388270359313958
# bpd (running average): 2.2388402275388026
# bpd (running average): 2.2389928181050043
# bpd (running average): 2.2389309167996454
# bpd (running average): 2.2388477740119783
# bpd (running average): 2.238912197442805
# bpd (running average): 2.2390448362338673
# bpd (running average): 2.2391609242907893
# bpd (running average): 2.2392959827643053
# bpd (running average): 2.2393310522281538
# bpd (running average): 2.2393558508479052
# bpd (running average): 2.239213214401575
# bpd (running average): 2.2389778688919093
# bpd (running average): 2.2388617680567293
# bpd (running average): 2.2386220137470922
# bpd (running average): 2.2389797111130805
# bpd (running average): 2.238941745960613
# bpd (running average): 2.239088695385797
# bpd (running average): 2.2389477870021066
# bpd (running average): 2.2388868709028418
# bpd (running average): 2.238775420634813
# bpd (running average): 2.2387476212272563
# bpd (running average): 2.2387565375995746
# bpd (running average): 2.2386894536612134
# bpd (running average): 2.238696825075424
# bpd (running average): 2.2387576226810353
# bpd (running average): 2.2386590052085316
# bpd (running average): 2.2386574178252068
# bpd (running average): 2.2384435251602017
# bpd (running average): 2.238556019066085
# bpd (running average): 2.23834508955017
# bpd (running average): 2.2382389305223516
# bpd (running average): 2.237902676150773
# bpd (running average): 2.237956951588604
# bpd (running average): 2.2380587441566844
# bpd (running average): 2.238091786410248
# bpd (running average): 2.2381071499335436
# bpd (running average): 2.2383351547668013
# bpd (running average): 2.23829871495329
# bpd (running average): 2.238241784991694
# bpd (running average): 2.2382031974912717
# bpd (running average): 2.2380591291506953
# bpd (running average): 2.2379267005471446
# bpd (running average): 2.2379283300725055
# bpd (running average): 2.2378612813491574
# bpd (running average): 2.2378368748190773
# bpd (running average): 2.2379226760979507
# bpd (running average): 2.237948143405566
# bpd (running average): 2.2378591597850974
# bpd (running average): 2.237836858614803
# bpd (running average): 2.238032336684399
# bpd (running average): 2.2380997782309433
# bpd (running average): 2.2380588239610892
# bpd (running average): 2.2378200532359
# bpd (running average): 2.2376243444909143
# bpd (running average): 2.23767249829617
# bpd (running average): 2.237382302067566
# bpd (running average): 2.2370676812827703
# bpd (running average): 2.237099084357947
# bpd (running average): 2.2371316971422788
# bpd (running average): 2.2373134524238822
# bpd (running average): 2.237525357605828
# bpd (running average): 2.2374560844518347
# bpd (running average): 2.237599213708224
# bpd (running average): 2.2376016944555035
# bpd (running average): 2.2376419494260964
# bpd (running average): 2.2376337949146805
# bpd (running average): 2.2376070923605353
# bpd (running average): 2.237651344524183
# bpd (running average): 2.2378513905946087
# bpd (running average): 2.2378773123898723
# bpd (running average): 2.23772162828784
# bpd (running average): 2.23798736306584
# bpd (running average): 2.2378862653922584
# bpd (running average): 2.2377790456983164
# bpd (running average): 2.2380626011833917
# bpd (running average): 2.2380689795320285
# bpd (running average): 2.2381173610066916
# bpd (running average): 2.2378896396779804
# bpd (running average): 2.2380428571394453
# bpd (running average): 2.2382525569586424
# bpd (running average): 2.238415173495557
# bpd (running average): 2.238509167552569
# bpd (running average): 2.2384897527251155
# bpd (running average): 2.2385124683748567
# bpd (running average): 2.2385646651915283
# bpd (running average): 2.238595973171465
# bpd (running average): 2.238652338181513
# bpd (running average): 2.2387091237026815
# bpd (running average): 2.238731625621432
# bpd (running average): 2.2388563861565807
# bpd (running average): 2.238979535069278
# bpd (running average): 2.2388122268036863
# bpd (running average): 2.2388026606995557
# bpd (running average): 2.2386472068565615
# bpd (running average): 2.2387746006860745
# bpd (running average): 2.238712179621008
# bpd (running average): 2.2387572245431206
# bpd (running average): 2.2392652827960635
# bpd (running average): 2.2392722190704126
# bpd (running average): 2.2391032925912566
# bpd (running average): 2.239010087499535
# bpd (running average): 2.239027656290505
# bpd (running average): 2.2390319780491263
# bpd (running average): 2.2390984516406465
# bpd (running average): 2.23895788785332
# bpd (running average): 2.239000699464648
# bpd (running average): 2.2389047778706668
# bpd (running average): 2.238961689317289
# bpd (running average): 2.238979216552658
# bpd (running average): 2.239124455964889
# bpd (running average): 2.238890455090625
# bpd (running average): 2.238803480765495
# bpd (running average): 2.2389553047549837
# bpd (running average): 2.2388057402683175
# bpd (running average): 2.2388510053337947
# bpd (running average): 2.238924378014535
# bpd (running average): 2.238699121246626
# bpd (running average): 2.238592770385414
# bpd (running average): 2.238565898044784
# bpd (running average): 2.238412359784838
# bpd (running average): 2.2385518519833054
# bpd (running average): 2.2386309102820205
# bpd (running average): 2.238706951274966
# bpd (running average): 2.238470400675598
# bpd (running average): 2.23834375739956
# bpd (running average): 2.238462571507127
# bpd (running average): 2.238527182970729
# bpd (running average): 2.238366645634194
# bpd (running average): 2.238398463515942
# bpd (running average): 2.238474997019124
# bpd (running average): 2.2386083527912835
# bpd (running average): 2.238686388626863
# bpd (running average): 2.238853965214172
# bpd (running average): 2.2389611363632724
# bpd (running average): 2.239071992843393
# bpd (running average): 2.2390975124864596
# bpd (running average): 2.2391830511452233
# bpd (running average): 2.2391291739228794
# bpd (running average): 2.2390831625396816
# bpd (running average): 2.239010201583528
# bpd (running average): 2.2390507631839407
# bpd (running average): 2.238784719791396
# bpd (running average): 2.238895686063215
# bpd (running average): 2.23886999785282
# bpd (running average): 2.238707259642884
# bpd (running average): 2.238699610827141
# bpd (running average): 2.238299635656667
# bpd (running average): 2.238347966867563
# bpd (running average): 2.238253558843791
# bpd (running average): 2.2383258380869897
# bpd (running average): 2.238249742109292
# bpd (running average): 2.238260009817683
# bpd (running average): 2.2384978106816007
# bpd (running average): 2.2385096806237152
# bpd (running average): 2.2385794651291233
# bpd (running average): 2.238741308190855
# bpd (running average): 2.238869472007453
# bpd (running average): 2.2388600587654848
# bpd (running average): 2.238965744644469
# bpd (running average): 2.2389830291844106
# bpd (running average): 2.239085857967927
# bpd (running average): 2.239043952645779
# bpd (running average): 2.239159711502576
# bpd (running average): 2.2391429961623293
# bpd (running average): 2.239055589314256
# bpd (running average): 2.239075737956011
# bpd (running average): 2.2390500594764253
# bpd (running average): 2.2390566087132657
# bpd (running average): 2.2387681641671087
# bpd (running average): 2.2386333151720503
# bpd (running average): 2.2387118574604643
# bpd (running average): 2.2387386686292956
# bpd (running average): 2.2388320022099317
# bpd (running average): 2.2388848114791404
# bpd (running average): 2.2387569986233276
# bpd (running average): 2.238895703311731
# bpd (running average): 2.2389579230366654
# bpd (running average): 2.2389478153353606
# bpd (running average): 2.2387707383972053
# bpd (running average): 2.23871531664983
# bpd (running average): 2.238758083380778
# bpd (running average): 2.2386660124622777
# bpd (running average): 2.2387428321498746
# bpd (running average): 2.2386990336843375
# bpd (running average): 2.238961551903122
# bpd (running average): 2.2390070530746073
# bpd (running average): 2.23876493026707
# bpd (running average): 2.2388270499889327
# bpd (running average): 2.238839842475068
# bpd (running average): 2.2386333560222664
# bpd (running average): 2.238540688651661
# bpd (running average): 2.2384156506907833
# bpd (running average): 2.238481350055193
# bpd (running average): 2.2386105859484573
# bpd (running average): 2.2386819337523396
# bpd (running average): 2.238762847213317
# bpd (running average): 2.2386483901245766
# bpd (running average): 2.238664036868438
# bpd (running average): 2.238604821162783
# bpd (running average): 2.2388340202355383
# bpd (running average): 2.2387934533764087
# bpd (running average): 2.238913991429964
# bpd (running average): 2.2390014139573027
# bpd (running average): 2.2390436383206382
# bpd (running average): 2.239160400381288
# bpd (running average): 2.2392487070789064
# bpd (running average): 2.2394329563724495
# bpd (running average): 2.2394713604690204
# bpd (running average): 2.239506575885793
# bpd (running average): 2.239336709193016
# bpd (running average): 2.239342132947491
# bpd (running average): 2.2392453761637467
# bpd (running average): 2.2393539704628913
# bpd (running average): 2.2394925430012607
# bpd (running average): 2.2396638013891623
# bpd (running average): 2.239845890695193
# bpd (running average): 2.2399519114387445
# bpd (running average): 2.2400847683872764
# bpd (running average): 2.239969524095603
# bpd (running average): 2.240240096694333
# bpd (running average): 2.2402832445778125
# bpd (running average): 2.240235200062444
# bpd (running average): 2.240099662025051
# bpd (running average): 2.2399739027194037
# bpd (running average): 2.2398933406778165
# bpd (running average): 2.2399933870506974
# bpd (running average): 2.240095740523227
# bpd (running average): 2.240051419821998
# bpd (running average): 2.239972015647081
# bpd (running average): 2.239985506929337
# bpd (running average): 2.240075224874771
# bpd (running average): 2.2401875030376086
# bpd (running average): 2.2402154777860184
# bpd (running average): 2.2401595744578944
# bpd (running average): 2.2403402913564747
# bpd (running average): 2.2402608535793567
# bpd (running average): 2.240249531747313
# bpd (running average): 2.240227597987269
# bpd (running average): 2.2402744137320827
# bpd (running average): 2.2403361115535403
# bpd (running average): 2.240369766487707
# bpd (running average): 2.240281424875409
# bpd (running average): 2.2404016912363147
# bpd (running average): 2.2405003620047634
# bpd (running average): 2.24043247029959
# bpd (running average): 2.240371910546092
# bpd (running average): 2.240383240341437
# bpd (running average): 2.240370360180654
# bpd (running average): 2.2404825254479626
# bpd (running average): 2.2404413198602136
# bpd (running average): 2.240364382892313
# bpd (running average): 2.2401363244252983
# bpd (running average): 2.240145863506158
# bpd (running average): 2.240235554571484
# bpd (running average): 2.2403261928814437
# bpd (running average): 2.2403884750178986
# bpd (running average): 2.2404762512134475
# bpd (running average): 2.2402836818310226
# bpd (running average): 2.2401359396394
# bpd (running average): 2.2403200298711607
# bpd (running average): 2.2404105532176217
# bpd (running average): 2.2403414133553
# bpd (running average): 2.240366590163503
# bpd (running average): 2.240248960891389
# bpd (running average): 2.2401765172470576
# bpd (running average): 2.240236031008163
# bpd (running average): 2.2401345091580698
# bpd (running average): 2.24015381687845
# bpd (running average): 2.2401390321069097
# bpd (running average): 2.2401504379111095
# bpd (running average): 2.240038597924644
# bpd (running average): 2.2398266000817673
# bpd (running average): 2.239719081794834
# bpd (running average): 2.2395949133720543
# bpd (running average): 2.239620068499676
# bpd (running average): 2.239537611269518
# bpd (running average): 2.239285334128137
# bpd (running average): 2.239153899208305
# bpd (running average): 2.2390734836829562
# bpd (running average): 2.2391045933897704
# bpd (running average): 2.2391831429993094
# bpd (running average): 2.2391073998707847
# bpd (running average): 2.2391113552175423
# bpd (running average): 2.2391076527536105
# bpd (running average): 2.2393381336159686
# bpd (running average): 2.2393010286107997
# bpd (running average): 2.239157897328599
# bpd (running average): 2.2391531625380257
# bpd (running average): 2.2390880883695514
# bpd (running average): 2.2391368451890505
# bpd (running average): 2.2393152422564446
# bpd (running average): 2.239292507492582
# bpd (running average): 2.2393210233096035
# bpd (running average): 2.2394546016333448
# bpd (running average): 2.2391805310632362
# bpd (running average): 2.2392158693956445
# bpd (running average): 2.2393560350178943
# bpd (running average): 2.2392041316513867
# bpd (running average): 2.239052888037303
# bpd (running average): 2.2390696381435307
# bpd (running average): 2.239083887061499
# bpd (running average): 2.2390354645913995
# bpd (running average): 2.238914463504457
# bpd (running average): 2.238807948564571
# bpd (running average): 2.2388129863834436
# bpd (running average): 2.238828337633755
# ...
# bpd (running average): 2.240496276266551
# bpd (running average): 2.2405257306113557
# bpd (running average): 2.240551699718852
# bpd (running average): 2.240673180131984
# bpd (running average): 2.2407357071012317
# bpd (running average): 2.2406118843364298
# bpd (running average): 2.2405976735929714
# bpd (running average): 2.2406242728987014
# bpd (running average): 2.240657994488499
# bpd (running average): 2.240678162970991
# bpd (running average): 2.2407837619721276
# bpd (running average): 2.240825410594402
# bpd (running average): 2.2408401919601872
# bpd (running average): 2.2408960632201946
# bpd (running average): 2.240870491426451
# bpd (running average): 2.240835392637404
# bpd (running average): 2.2407521922203744
# bpd (running average): 2.240848841751761
# bpd (running average): 2.240972592858532
# bpd (running average): 2.2410207406221265
# bpd (running average): 2.2410058314742076
# bpd (running average): 2.2409882455369665
# bpd (running average): 2.2409961299628667
# bpd (running average): 2.2408993747911077
# bpd (running average): 2.2408125270746746
# bpd (running average): 2.2407663212676967
# bpd (running average): 2.24073966793802
# bpd (running average): 2.2407029247159476
# bpd (running average): 2.240611634476198
# bpd (running average): 2.240669756676925
# bpd (running average): 2.240654752164702
# bpd (running average): 2.2406501567038677
# bpd (running average): 2.240787617677785
# bpd (running average): 2.240813655542222
# bpd (running average): 2.2406881434286046
# bpd (running average): 2.2408516671953667
# bpd (running average): 2.2407026943797375
# bpd (running average): 2.24065436113395
# bpd (running average): 2.2406953148377364
# bpd (running average): 2.2407850674077214
# bpd (running average): 2.240932309351825
# bpd (running average): 2.240862213897468
# bpd (running average): 2.240900472651154
# bpd (running average): 2.240901946029662
# bpd (running average): 2.240907234935926
# bpd (running average): 2.24104938278099
# bpd (running average): 2.2410041981042346
# bpd (running average): 2.2409279465254173
# bpd (running average): 2.2408849376725173
# bpd (running average): 2.2408147954258197
# bpd (running average): 2.2407908807291994
# bpd (running average): 2.2408501165917176
# bpd (running average): 2.2407838905914033
# bpd (running average): 2.2407807918609293
# bpd (running average): 2.2407254164782406
# bpd (running average): 2.2406410650156467
# bpd (running average): 2.2404629717793862
# bpd (running average): 2.240504599726814
# bpd (running average): 2.2404079149463056
# bpd (running average): 2.2404469766618376
# bpd (running average): 2.240352968313698
# bpd (running average): 2.2404537472405988
# bpd (running average): 2.240372579410657
# bpd (running average): 2.2404847931456633
# bpd (running average): 2.240503471692224
# bpd (running average): 2.240582030305701
# bpd (running average): 2.240440007758697
# bpd (running average): 2.2403851478039774
# bpd (running average): 2.240308521344585
# bpd (running average): 2.2403078853376126
# bpd (running average): 2.24028847593347
# bpd (running average): 2.2401664602563764
# bpd (running average): 2.240130614455294
# bpd (running average): 2.2401248676393624
# bpd (running average): 2.2401770911118337
# bpd (running average): 2.240168661436882
# bpd (running average): 2.240152715010342
# bpd (running average): 2.240100865825724
# bpd (running average): 2.2401182806405022
# bpd (running average): 2.239990682839211
# bpd (running average): 2.2399134398320535
# bpd (running average): 2.239906307818101
# bpd (running average): 2.2398568020381764
# bpd (running average): 2.239926490866816
# bpd (running average): 2.2399449720708393
# bpd (running average): 2.2398965252156455
# bpd (running average): 2.2399661207776305
# bpd (running average): 2.239820930707313
# bpd (running average): 2.239878931202773
# bpd (running average): 2.2398596322775113
# bpd (running average): 2.239875337429867
# bpd (running average): 2.239987808641834
# bpd (running average): 2.2399729428659523
# bpd (running average): 2.239963543977945
# bpd (running average): 2.2399545330680657
# bpd (running average): 2.2399505550993366
# bpd (running average): 2.2398311488773976
# bpd (running average): 2.239897651366518
# bpd (running average): 2.2398470725828346
# bpd (running average): 2.239890931560731
# bpd (running average): 2.2398982827035656
# bpd (running average): 2.2398266356341066
# bpd (running average): 2.239712100366004
# bpd (running average): 2.239754800366792
# bpd (running average): 2.2397543093823744
# bpd (running average): 2.239793157386701
# bpd (running average): 2.239842231692521
# bpd (running average): 2.2399052122383782
# bpd (running average): 2.2398502713291033
# bpd (running average): 2.239826990073299
# bpd (running average): 2.2398349299827256
# bpd (running average): 2.239763343322292
# bpd (running average): 2.2397532820670003
# bpd (running average): 2.23978398037387
# bpd (running average): 2.2399134660434643
# bpd (running average): 2.2398495388258994
# bpd (running average): 2.2398646272980423
# bpd (running average): 2.2397796620551307
# bpd (running average): 2.23967208193704
# bpd (running average): 2.239728848093846
# bpd (running average): 2.2396443159111956
# bpd (running average): 2.2396951783520302
# bpd (running average): 2.2397198011769
# bpd (running average): 2.2397022102410884
# bpd (running average): 2.2396946454391484
# bpd (running average): 2.239553800173013
# bpd (running average): 2.239604499449038
# bpd (running average): 2.2395458557999555
# bpd (running average): 2.239548700256291
# bpd (running average): 2.2395181023523163
# bpd (running average): 2.239391919967702
# bpd (running average): 2.2393811984169645
# bpd (running average): 2.2394362507951686
# bpd (running average): 2.2394756120427455
# bpd (running average): 2.2395729286229766
# bpd (running average): 2.2395706313111248
# bpd (running average): 2.2395068911629123
# bpd (running average): 2.2394784577903333
# bpd (running average): 2.239628605795917
# bpd (running average): 2.239589427609525
# bpd (running average): 2.239561786354361
# bpd (running average): 2.23947115534146
# bpd (running average): 2.2395136602702936
# bpd (running average): 2.23950891005731
# bpd (running average): 2.239485407100738
# bpd (running average): 2.239592724301312
# bpd (running average): 2.239420385968263
# bpd (running average): 2.2394217733253856
# bpd (running average): 2.239467880707717
# bpd (running average): 2.239528655700068
# bpd (running average): 2.2395758616991643
# bpd (running average): 2.23960035508896
# bpd (running average): 2.239438827614569
# bpd (running average): 2.2395324800721275
# bpd (running average): 2.2395465450391
# bpd (running average): 2.239384804626221
# bpd (running average): 2.239334449648995
# bpd (running average): 2.2392504533407953
# bpd (running average): 2.2392872814970084
# bpd (running average): 2.239304583594947
# bpd (running average): 2.239078846790134
# bpd (running average): 2.2389621594754567
# bpd (running average): 2.239011473143413
# bpd (running average): 2.239042738896132
# bpd (running average): 2.2390952784024316
# bpd (running average): 2.239085205907307
# bpd (running average): 2.238971131939114
# bpd (running average): 2.2389439590123104
# bpd (running average): 2.2389275678297165
# bpd (running average): 2.2388522984089
# bpd (running average): 2.238965240822923
# bpd (running average): 2.2390451810838075
# bpd (running average): 2.23902930984962
# bpd (running average): 2.2390326887257563
# bpd (running average): 2.2390509178950206
# bpd (running average): 2.2391602593230604
# bpd (running average): 2.2392016327667656
# bpd (running average): 2.239146798371046
# bpd (running average): 2.2391664866289367
# bpd (running average): 2.2392773094868055
# bpd (running average): 2.239243891908129
# bpd (running average): 2.2393315178042155
# bpd (running average): 2.23950717880022
# bpd (running average): 2.2394499972559108
# bpd (running average): 2.239412656288762
# bpd (running average): 2.239426010963796
# bpd (running average): 2.239487427313952
# bpd (running average): 2.2394817860320844
# bpd (running average): 2.2395418894858077
# bpd (running average): 2.2395498987632423
# bpd (running average): 2.2396261912441258
# bpd (running average): 2.2396201213561473
# bpd (running average): 2.239506771015197
# bpd (running average): 2.239527786767927
# bpd (running average): 2.239558935587547
# bpd (running average): 2.239643577332654
# bpd (running average): 2.239770195677809
# bpd (running average): 2.239725058692223
# bpd (running average): 2.239764796358313
# bpd (running average): 2.239673714758562
# bpd (running average): 2.239645450663697
# bpd (running average): 2.239655135129203
# bpd (running average): 2.2396822647016688
# bpd (running average): 2.2395699990358877
# bpd (running average): 2.239585345955923
# bpd (running average): 2.239704010772108
# bpd (running average): 2.239659041026843
# bpd (running average): 2.239581386926227
# bpd (running average): 2.2394703633366477
# bpd (running average): 2.239305720046277
# bpd (running average): 2.23921075711585
# bpd (running average): 2.2392514036915685
# bpd (running average): 2.2392077810872717
# bpd (running average): 2.2392027554410143
# bpd (running average): 2.2391824657515236
# bpd (running average): 2.2393237194896676
# bpd (running average): 2.2392823556471586
# bpd (running average): 2.2393354857627203
# bpd (running average): 2.2392615375508544
# bpd (running average): 2.2392080932538
# bpd (running average): 2.239101068160758
# bpd (running average): 2.239133616128167
# bpd (running average): 2.239241662511492
# bpd (running average): 2.2392270950434687
# bpd (running average): 2.2393183866324473
# bpd (running average): 2.23927487741454
# bpd (running average): 2.2393067383467162
# bpd (running average): 2.239384826935082
# bpd (running average): 2.2393199210366173
# bpd (running average): 2.2392374400885444
# bpd (running average): 2.2391736270144693
# bpd (running average): 2.2391614943172997
# bpd (running average): 2.239255112302432
# bpd (running average): 2.2391576884825493
# bpd (running average): 2.239144408240001
# bpd (running average): 2.2391015727550925
# bpd (running average): 2.239044082515559
# bpd (running average): 2.2389083853248386
# bpd (running average): 2.238879850433562
# bpd (running average): 2.238872027305711
# bpd (running average): 2.2389380268645676
# bpd (running average): 2.2390557138620735
# bpd (running average): 2.239087135896406
# bpd (running average): 2.2390567902274365
# bpd (running average): 2.239191490891039
# bpd (running average): 2.239231881369047
# bpd (running average): 2.239123021856643
# bpd (running average): 2.239019839384203
# bpd (running average): 2.2389848878803433
# bpd (running average): 2.238986707023945
# bpd (running average): 2.2388544039371867
# bpd (running average): 2.238847287607129
# bpd (running average): 2.2388849001303486
# bpd (running average): 2.238872534925668
# bpd (running average): 2.2389165742930075
# bpd (running average): 2.2388702892948023
# bpd (running average): 2.2388077861548643
# bpd (running average): 2.238829904413183
# bpd (running average): 2.2388650483647208
# bpd (running average): 2.23887852807691
# bpd (running average): 2.238815217511134
# bpd (running average): 2.2388165715453474
# bpd (running average): 2.23883746741477
# bpd (running average): 2.2388619113276405
# bpd (running average): 2.238796139366996
# bpd (running average): 2.238786429571549
# bpd (running average): 2.238799083419272
# bpd (running average): 2.2388142123617
# bpd (running average): 2.2389121132976384
# bpd (running average): 2.2389552940081323
# bpd (running average): 2.2389300212511882
# bpd (running average): 2.238927642288566
# bpd (running average): 2.238856741767305
# bpd (running average): 2.238770857861144
# bpd (running average): 2.238772895858678
# bpd (running average): 2.2388238318437734
# bpd (running average): 2.238806342905698
# bpd (running average): 2.238912074404427
# bpd (running average): 2.238940335021231
# bpd (running average): 2.238990048015533
# bpd (running average): 2.2389931511089314
# bpd (running average): 2.2390062864087312
# bpd (running average): 2.238938884183493
# bpd (running average): 2.2389104552809838
# bpd (running average): 2.2390051412804723
# bpd (running average): 2.239072957819349
# bpd (running average): 2.2390203305811247
# bpd (running average): 2.238992751320444
# bpd (running average): 2.238973329781175
# bpd (running average): 2.2389945074603927
# bpd (running average): 2.2388888518866876
# bpd (running average): 2.238990137764244
# bpd (running average): 2.238989439002787
# bpd (running average): 2.23899921716611
# bpd (running average): 2.239090265942671
# bpd (running average): 2.2390883153699006
# bpd (running average): 2.2391769081528183
# bpd (running average): 2.2391899179303643
# bpd (running average): 2.2392200819272605
# bpd (running average): 2.239275754842278
# bpd (running average): 2.2394097491456195
# bpd (running average): 2.2392531962375815
# bpd (running average): 2.2392271038368405
# bpd (running average): 2.2392099449909937
# bpd (running average): 2.239229727601433
# bpd (running average): 2.2391858073062734
# bpd (running average): 2.239118048097089
# bpd (running average): 2.2391172974662505
# bpd (running average): 2.2389299879588056
# bpd (running average): 2.23891147498735
# bpd (running average): 2.2390363948575316
# bpd (running average): 2.2388954850857257
# bpd (running average): 2.2389178190940293
# bpd (running average): 2.2389936359211866
# bpd (running average): 2.2389645803305602
# bpd (running average): 2.239003963768624
# bpd (running average): 2.238961969925336
# bpd (running average): 2.238930033466521
# bpd (running average): 2.2389313470516106
# bpd (running average): 2.2389388941693427
# bpd (running average): 2.2389167272631236
# bpd (running average): 2.238844459642996
# bpd (running average): 2.2388351406187104
# bpd (running average): 2.238829358853373
# bpd (running average): 2.238865177508861
# bpd (running average): 2.2389320453982005
# bpd (running average): 2.2389118307921287
# bpd (running average): 2.238931093355427
# bpd (running average): 2.238991288662683
# bpd (running average): 2.238987279734116
# bpd (running average): 2.2388612305692863
# bpd (running average): 2.238874407206384
# bpd (running average): 2.238874152306236
# bpd (running average): 2.2389045567023733
# bpd (running average): 2.2390050798685084
# bpd (running average): 2.23909412040165
# bpd (running average): 2.23914537316944
# bpd (running average): 2.2391275773124764
# bpd (running average): 2.239243005744891
# bpd (running average): 2.23929041407155
# bpd (running average): 2.2393434418215263
# bpd (running average): 2.2393239969811254
# bpd (running average): 2.2392226720189106
# bpd (running average): 2.239217849539634
# bpd (running average): 2.2393209859246848
# bpd (running average): 2.2394046459078485
# bpd (running average): 2.2394328489071453
# bpd (running average): 2.239417740090261
# bpd (running average): 2.239411776611126
# bpd (running average): 2.2394144249553687
# bpd (running average): 2.239317554015435
# bpd (running average): 2.239343332379166
# bpd (running average): 2.239272153638013
# bpd (running average): 2.2393137650585446
# bpd (running average): 2.2393510390326528
# bpd (running average): 2.239219310215578
# bpd (running average): 2.2391675385044536
# bpd (running average): 2.2392179463320074
# bpd (running average): 2.239332725641117
# bpd (running average): 2.239281892255507
# bpd (running average): 2.2392761812231865
# bpd (running average): 2.239183472068592
# bpd (running average): 2.2392058485531137
# bpd (running average): 2.239202633397007
# bpd (running average): 2.239222108811516
# bpd (running average): 2.2392230791240286
# bpd (running average): 2.239204783911731
# bpd (running average): 2.239209912129195
# bpd (running average): 2.2391770192843965
# bpd (running average): 2.2392312443907474
# bpd (running average): 2.239304327516558
# bpd (running average): 2.239170849418445
# bpd (running average): 2.2390790995925007
# bpd (running average): 2.2388340301037806
# bpd (running average): 2.2387343991825133
# bpd (running average): 2.238672018968324
# bpd (running average): 2.23865246802983
# bpd (running average): 2.238806081118746
# bpd (running average): 2.2387815553173045
# bpd (running average): 2.23878056739385
# bpd (running average): 2.2387329291205287
# bpd (running average): 2.238731210063069
# bpd (running average): 2.238689740357576
# bpd (running average): 2.2387844234501237
# bpd (running average): 2.2388484267626447
# bpd (running average): 2.2387277446378198

# %% [markdown]
# ## Further Resources
#
# If you're interested in learning more about score-based generative models, the following papers would be a good start:
#
# *   Yang Song, and Stefano Ermon. "[Generative modeling by estimating gradients of the data distribution.](https://arxiv.org/pdf/1907.05600.pdf)" Advances in Neural Information Processing Systems. 2019.
# *    Yang Song, and Stefano Ermon. "[Improved Techniques for Training Score-Based Generative Models.](https://arxiv.org/pdf/2006.09011.pdf)" Advances in Neural Information Processing Systems. 2020.
# * Jonathan Ho, Ajay Jain, and Pieter Abbeel. "[Denoising diffusion probabilistic models.](https://arxiv.org/pdf/2006.11239.pdf)" Advances in Neural Information Processing Systems. 2020.
